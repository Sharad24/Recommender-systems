# %%
import json
from flask import Flask, jsonify, request
from flask_pymongo import PyMongo
import pymongo
from pymongo import MongoClient
client = MongoClient()
db1 = client.imdb_movies

app = Flask(__name__)

app.config['Mongo_DBNAME'] = 'imdb_movies'
app.config['MONGO_URI'] = 'mongodb://localhost:27010/imdb_movies'

mongo = PyMongo(app)

@app.route('/add')
def add_user():
    user = mongo.db.users
    user.insert({'name':"Sharad"})
    return "Added User"

@app.route('/find', methods = ['GET'])
def find():
    user = mongo.db.post.find()
    for doc in data:
        pprint(doc)
    return "You found " + str(doc['name'])

@app.route('/collection')
def find_collection():
    collection = db1.post
    data = collection.find()
    for document in data:
        pprint(document)
    return "You found"

# %%
mongo.db.collection_names(include_system_collections=False)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: collection_names is deprecated. Use list_collection_names instead.
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# <ipython-input-47-152efce5d569> in <module>()
# ----> 1 mongo.db.collection_names(include_system_collections=False)
#
# /anaconda3/lib/python3.6/site-packages/pymongo/database.py in collection_names(self, include_system_collections, session)
#     713         return [result["name"]
#     714                 for result in self.list_collections(session=session,
# --> 715                                                     nameOnly=True, **kws)]
#     716
#     717     def drop_collection(self, name_or_collection, session=None):
#
# ...

# %%
from pprint import pprint

cursor = post.find()
for document in cursor: 
    pprint(document)
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# <ipython-input-50-61bedaac5575> in <module>()
#       2
#       3 cursor = post.find()
# ----> 4 for document in cursor:
#       5     pprint(document)
#
# /anaconda3/lib/python3.6/site-packages/pymongo/cursor.py in next(self)
#    1187         if self.__empty:
#    1188             raise StopIteration
# -> 1189         if len(self.__data) or self._refresh():
#    1190             if self.__manipulate:
#    1191                 _db = self.__collection.database
#
# /anaconda3/lib/python3.6/site-packages/pymongo/cursor.py in _refresh(self)
#    1085
#    1086         if not self.__session:
# -> 1087             self.__session = self.__collection.database.client._ensure_session()
#    1088
#    1089         if self.__id is None:  # Query
#
# ...

# %%
mongo.db.post.find()

# %%
pprint(posts.find())

# %%
#db.collection_names(include_system_collections=False)

# %%
find()
# Out:
# ...
# 'You found '

# %%
find_collection()
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# <ipython-input-62-37bdafb9765c> in <module>()
# ----> 1 find_collection()
#
# <ipython-input-61-2edce7c9b31c> in find_collection()
#      31     collection = db1.post
#      32     data = collection.find()
# ---> 33     for document in data:
#      34         pprint(document)
#      35     return "You found"
#
# /anaconda3/lib/python3.6/site-packages/pymongo/cursor.py in next(self)
#    1187         if self.__empty:
#    1188             raise StopIteration
# -> 1189         if len(self.__data) or self._refresh():
#    1190             if self.__manipulate:
#    1191                 _db = self.__collection.database
#
# /anaconda3/lib/python3.6/site-packages/pymongo/cursor.py in _refresh(self)
#    1085
#    1086         if not self.__session:
# ...

# %%
data = db1.post.find()
for doc in data:
    pprint(doc)
# Out:
# {'_id': ObjectId('5c634a5ce3c0160aef1e93fd'),
#  'release': '1995',
#  'thumbnail_addr': 'https://m.media-amazon.com/images/M/MV5BMDU2ZWJlMjktMTRhMy00ZTA5LWEzNDgtYmNmZTEwZTViZWJkXkEyXkFqcGdeQXVyNDQ2OTk4MzI@._V1_.jpg',
#  'title': 'Toy Story'}
# {'_id': ObjectId('5c634a5ce3c0160aef1e93fe'),
#  'release': '1995',
#  'thumbnail_addr': 'https://m.media-amazon.com/images/M/MV5BZTk2ZmUwYmEtNTcwZS00YmMyLWFkYjMtNTRmZDA3YWExMjc2XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_.jpg',
#  'title': 'Jumanji'}
# {'_id': ObjectId('5c634a5ce3c0160aef1e93ff'),
#  'release': '1995',
#  'thumbnail_addr': 'https://m.media-amazon.com/images/M/MV5BMjQxM2YyNjMtZjUxYy00OGYyLTg0MmQtNGE2YzNjYmUyZTY1XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_.jpg',
#  'title': 'Grumpier Old Men'}
# {'_id': ObjectId('5c634a5ce3c0160aef1e9400'),
#  'release': '1995',
#  'thumbnail_addr': 'https://m.media-amazon.com/images/M/MV5BYzcyMDY2YWQtYWJhYy00OGQ2LTk4NzktYWJkNDYwZWJmY2RjXkEyXkFqcGdeQXVyMTA0MjU0Ng@@._V1_.jpg',
#  'title': 'Waiting to Exhale'}
# ...
